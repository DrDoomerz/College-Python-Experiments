# %% [markdown]
# Experiment 0: Introduction to Python

# %%
# Rachit Jajoo
# ENTC B1
# PRN: 25070123088

# %%
print("My name is Rachit Jajoo")
# Out:
# My name is Rachit Jajoo

# %%
print(2) # because 2 is the most epic number.
# Out:
# 2

# %%
print([1,2,5])
# Out:
# [1, 2, 5]

# %%
x = "My name is Rachit Jajoo"
y = 2
z = [1,2,5]
print(x,y,z,sep="\n")
# Out:
# My name is Rachit Jajoo
# 2
# [1, 2, 5]
