# %%
# Experiment 15: Data Normalization and Data Type Conversion
# Name: Rachit Jajoo
# PRN: 25070123088
# Batch: ENTC - B1

# %% [markdown]
# Part A: Data Normalization

# %%
# Importing Dataset 1
import pandas as pd
import numpy as np

data = {
    'Product': ['Laptop', 'Mobile', 'Tablet', 'Headphones', 'Smartwatch', 'Camera'],
    'Price': [55000, 20000, 30000, 2000, 8000, 45000],
    'Units_Sold': [25, 60, 35, 80, 50, 15],
    'Discount': [10,15,12,20,18,8]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Product  Price  Units_Sold  Discount
# 0      Laptop  55000          25        10
# 1      Mobile  20000          60        15
# 2      Tablet  30000          35        12
# 3  Headphones   2000          80        20
# 4  Smartwatch   8000          50        18
# 5      Camera  45000          15         8

# %%
# Dataset 1 Code 1:  Min-Max Normalization for Price

df['Price_MinMax'] = (df['Price'] - df['Price'].min()) / (df['Price'].max() - df['Price'].min())

print("\n Min-Max Normalized Price \n")
print(df[['Product', 'Price', 'Price_MinMax']])
# Out:
#  Min-Max Normalized Price
#
#       Product  Price  Price_MinMax
# 0      Laptop  55000      1.000000
# 1      Mobile  20000      0.339623
# 2      Tablet  30000      0.528302
# 3  Headphones   2000      0.000000
# 4  Smartwatch   8000      0.113208
# 5      Camera  45000      0.811321

# %%
# Dataset 1 Code 2: Normalizing Multiple Columns

cols = ['Price', 'Units_Sold', 'Discount']
df_norm = (df[cols] - df[cols].min()) / (df[cols].max() - df[cols].min())

print("\n Normalized Dataset \n")
print(df_norm)
# Out:
#  Normalized Dataset
#
#       Price  Units_Sold  Discount
# 0  1.000000    0.153846  0.166667
# 1  0.339623    0.692308  0.583333
# 2  0.528302    0.307692  0.333333
# 3  0.000000    1.000000  1.000000
# 4  0.113208    0.538462  0.833333
# 5  0.811321    0.000000  0.000000

# %%
# Dataset 1 Code 3: Z score Normalization

df['Unit_Zscore'] = (df['Units_Sold'] - df['Units_Sold'].mean()) / df['Units_Sold'].std()

print("\n Z-Score Normalized Dataset \n")
print(df[['Product', 'Units_Sold', 'Unit_Zscore']])
# Out:
#  Z-Score Normalized Dataset
#
#       Product  Units_Sold  Unit_Zscore
# 0      Laptop          25    -0.799885
# 1      Mobile          60     0.660775
# 2      Tablet          35    -0.382554
# 3  Headphones          80     1.495437
# 4  Smartwatch          50     0.243443
# 5      Camera          15    -1.217216

# %%
# Dataset 1 Code 4: Decimal Scaling

df['Price_Decimal'] = df['Price'] / 100000

print("\n Decimal Scaled Dataset \n")
print(df[['Product', 'Price', 'Price_Decimal']])
# Out:
#  Decimal Scaled Dataset
#
#       Product  Price  Price_Decimal
# 0      Laptop  55000           0.55
# 1      Mobile  20000           0.20
# 2      Tablet  30000           0.30
# 3  Headphones   2000           0.02
# 4  Smartwatch   8000           0.08
# 5      Camera  45000           0.45

# %% [markdown]
# Part B: Turning Categorical Varables Into Quantitative Variables In Python

# %%
# Importing Dataset 2
import pandas as pd
import numpy as np
data = {
'Order_ID':[101,102,103,104,105,106],
'Customer_Gender':['Male','Female','Female','Male','Female','Male'],
'Payment_Method':['UPI','Credit Card','Debit Card','COD','UPI','Debit Card'],
'Product_Category':['Electronics','Clothing','Home','Electronics','Beauty','Electronics'],
'City':['Pune','Mumbai','Delhi','Bangalore','Pune','Hyderabad'],
'Order_Value':[4500,2300,3200,5200,1800,4100]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Order_ID Customer_Gender Payment_Method Product_Category       City  \
# 0       101            Male            UPI      Electronics       Pune
# 1       102          Female    Credit Card         Clothing     Mumbai
# 2       103          Female     Debit Card             Home      Delhi
# 3       104            Male            COD      Electronics  Bangalore
# 4       105          Female            UPI           Beauty       Pune
# 5       106            Male     Debit Card      Electronics  Hyderabad
#
#    Order_Value
# 0         4500
# 1         2300
# 2         3200
# 3         5200
# 4         1800
# 5         4100

# %%
# Dataset 2 Code 1: Label Encoding - method one
# https://scikit-learn.org/stable/ is the site to find the data for this.

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['Gender_Label'] = le.fit_transform(df['Customer_Gender'])
df['City_Label'] = le.fit_transform(df['City'])
print(df)
# Out:
#    Order_ID Customer_Gender Payment_Method Product_Category       City  \
# 0       101            Male            UPI      Electronics       Pune
# 1       102          Female    Credit Card         Clothing     Mumbai
# 2       103          Female     Debit Card             Home      Delhi
# 3       104            Male            COD      Electronics  Bangalore
# 4       105          Female            UPI           Beauty       Pune
# 5       106            Male     Debit Card      Electronics  Hyderabad
#
#    Order_Value  Gender_Label  City_Label
# 0         4500             1           4
# 1         2300             0           3
# 2         3200             0           1
# 3         5200             1           0
# 4         1800             0           4
# 5         4100             1           2

# %%
# Dataset 2 Code 2: One Hot Encoding - method two
df_encoded = pd.get_dummies(df, columns=['Payment_Method'])
print(df_encoded)
# Out:
#    Order_ID Customer_Gender Product_Category       City  Order_Value  \
# 0       101            Male      Electronics       Pune         4500
# 1       102          Female         Clothing     Mumbai         2300
# 2       103          Female             Home      Delhi         3200
# 3       104            Male      Electronics  Bangalore         5200
# 4       105          Female           Beauty       Pune         1800
# 5       106            Male      Electronics  Hyderabad         4100
#
#    Gender_Label  City_Label  Payment_Method_COD  Payment_Method_Credit Card  \
# 0             1           4               False                       False
# 1             0           3               False                        True
# 2             0           1               False                       False
# 3             1           0                True                       False
# 4             0           4               False                       False
# ...

# %%
# Dataset 2 Code 3: Dummy Encoding (drop first) - method three
df_dummy = pd.get_dummies(df, columns=['Payment_Method'], drop_first=True)
print(df_dummy)
# Out:
#    Order_ID Customer_Gender Product_Category       City  Order_Value  \
# 0       101            Male      Electronics       Pune         4500
# 1       102          Female         Clothing     Mumbai         2300
# 2       103          Female             Home      Delhi         3200
# 3       104            Male      Electronics  Bangalore         5200
# 4       105          Female           Beauty       Pune         1800
# 5       106            Male      Electronics  Hyderabad         4100
#
#    Gender_Label  City_Label  Payment_Method_Credit Card  \
# 0             1           4                       False
# 1             0           3                        True
# 2             0           1                       False
# 3             1           0                       False
# 4             0           4                       False
# 5             1           2                       False
#
#    Payment_Method_Debit Card  Payment_Method_UPI
# ...

# %% [markdown]
# # DIY Exercise
# We are tasked to perform the operations learnt in the experiment on new datasets.
# 2 Datasets are given by the professor, we are performing the operations on it by writing the code.

# %%
# Amazon Product Dataset: Normalization
import pandas as pd

df = pd.read_csv("Amazon_dataset_Expt-15.csv")

# Apply Min-Max Normalization on Price column
df['Price'] = (df['Price'] - df['Price'].min()) / (df['Price'].max() - df['Price'].min())

# Display updated dataset
df
# Out:
#    Product_ID                 Product_Name     Price  Rating  Reviews  \
# 0        P101               Wireless Mouse  0.020243     4.3     1520
# 1        P102            Bluetooth Speaker  0.048583     4.5      980
# 2        P103                 USB Keyboard  0.016194     4.1      870
# 3        P104               Gaming Headset  0.089069     4.6     2100
# 4        P105                   Smartwatch  0.149798     4.4     3050
# 5        P106                   Power Bank  0.036437     4.2     1750
# 6        P107                 Laptop Stand  0.024291     4.0      620
# 7        P108                       Webcam  0.064777     4.3     1120
# 8        P109                 Portable SSD  0.210526     4.7     1850
# 9        P110             Wireless Charger  0.028340     4.2      760
# 10       P111  Noise Cancelling Headphones  0.311741     4.6     4200
# 11       P112          Mechanical Keyboard  0.174089     4.5     2100
# ...

# %%
# Amazon Product Dataset: Z Score Normalization
import pandas as pd

df = pd.read_csv("Amazon_dataset_Expt-15.csv")

# Calculate mean and standard deviation of Price
mean_price = df['Price'].mean()
std_price = df['Price'].std()

# Apply Z-score normalization
df['Price'] = (df['Price'] - mean_price) / std_price

# Display result
df
# Out:
#    Product_ID                 Product_Name     Price  Rating  Reviews  \
# 0        P101               Wireless Mouse -0.692019     4.3     1520
# 1        P102            Bluetooth Speaker -0.557310     4.5      980
# 2        P103                 USB Keyboard -0.711263     4.1      870
# 3        P104               Gaming Headset -0.364869     4.6     2100
# 4        P105                   Smartwatch -0.076207     4.4     3050
# 5        P106                   Power Bank -0.615043     4.2     1750
# 6        P107                 Laptop Stand -0.672775     4.0      620
# 7        P108                       Webcam -0.480334     4.3     1120
# 8        P109                 Portable SSD  0.212455     4.7     1850
# 9        P110             Wireless Charger -0.653531     4.2      760
# 10       P111  Noise Cancelling Headphones  0.693559     4.6     4200
# 11       P112          Mechanical Keyboard  0.039258     4.5     2100
# ...

# %%
# Amazon Product Dataset: Decimal Scaling
import pandas as pd
df = pd.read_csv("Amazon_dataset_Expt-15.csv")

df['Price_Decimal'] = df['Price'] / 100000

print("\n Decimal Scaled Dataset \n")
print(df[['Product_Name', 'Price', 'Price_Decimal']])
# Out:
#  Decimal Scaled Dataset
#
#                    Product_Name  Price  Price_Decimal
# 0                Wireless Mouse    799        0.00799
# 1             Bluetooth Speaker   1499        0.01499
# 2                  USB Keyboard    699        0.00699
# 3                Gaming Headset   2499        0.02499
# 4                    Smartwatch   3999        0.03999
# 5                    Power Bank   1199        0.01199
# 6                  Laptop Stand    899        0.00899
# 7                        Webcam   1899        0.01899
# 8                  Portable SSD   5499        0.05499
# 9              Wireless Charger    999        0.00999
# 10  Noise Cancelling Headphones   7999        0.07999
# 11          Mechanical Keyboard   4599        0.04599
# 12                 Gaming Mouse   1599        0.01599
# 13                 Tablet Stand    699        0.00699
# 14                      USB Hub    899        0.00899
# 15          External Hard Drive   6499        0.06499
# ...

# %%
# Student Dataset: Turning categorical values into quantitative variables
df = pd.read_csv("Student_Dataset_Exp15.csv")
df
# Out:
#    Roll_No  Gender  Department  CGPA  Number_of_Backlogs  \
# 0      101  Female    Computer   8.2                   0
# 1      102    Male          IT   7.5                   1
# 2      103  Female        ENTC   9.1                   0
# 3      104    Male  Mechanical   6.8                   2
# 4      105  Female    Computer   8.7                   0
# 5      106    Male       Civil   7.2                   3
# 6      107  Female          IT   8.9                   0
# 7      108    Male    Computer   6.5                   1
# 8      109  Female        ENTC   7.8                   0
# 9      110    Male  Mechanical   7.0                   2
#
#    Attendance_Percentage Placement_Status  Salary
# 0                     92           Placed  450000
# 1                     85       Not Placed       0
# 2                     96           Placed  550000
# 3                     78       Not Placed       0
# 4                     88           Placed  480000
# ...

# %%
# Student Dataset: Label Encoding for Placement Status
from sklearn.preprocessing import LabelEncoder
import pandas as pd

df = pd.read_csv("Student_Dataset_Exp15.csv")

le = LabelEncoder()
df['Placement_Status'] = le.fit_transform(df['Placement_Status'])

df
# Out:
#    Roll_No  Gender  Department  CGPA  Number_of_Backlogs  \
# 0      101  Female    Computer   8.2                   0
# 1      102    Male          IT   7.5                   1
# 2      103  Female        ENTC   9.1                   0
# 3      104    Male  Mechanical   6.8                   2
# 4      105  Female    Computer   8.7                   0
# 5      106    Male       Civil   7.2                   3
# 6      107  Female          IT   8.9                   0
# 7      108    Male    Computer   6.5                   1
# 8      109  Female        ENTC   7.8                   0
# 9      110    Male  Mechanical   7.0                   2
#
#    Attendance_Percentage  Placement_Status  Salary
# 0                     92                 1  450000
# 1                     85                 0       0
# 2                     96                 1  550000
# 3                     78                 0       0
# 4                     88                 1  480000
# ...

# %%
# Student Dataset: One Hot Encoding for Department
import pandas as pd
df = pd.read_csv("Student_Dataset_Exp15.csv")

dept_encoded = pd.get_dummies(df['Department'], prefix='Dept')

df = pd.concat([df, dept_encoded], axis=1)

df
# Out:
#    Roll_No  Gender  Department  CGPA  Number_of_Backlogs  \
# 0      101  Female    Computer   8.2                   0
# 1      102    Male          IT   7.5                   1
# 2      103  Female        ENTC   9.1                   0
# 3      104    Male  Mechanical   6.8                   2
# 4      105  Female    Computer   8.7                   0
# 5      106    Male       Civil   7.2                   3
# 6      107  Female          IT   8.9                   0
# 7      108    Male    Computer   6.5                   1
# 8      109  Female        ENTC   7.8                   0
# 9      110    Male  Mechanical   7.0                   2
#
#    Attendance_Percentage Placement_Status  Salary  Dept_Civil  Dept_Computer  \
# 0                     92           Placed  450000       False           True
# 1                     85       Not Placed       0       False          False
# 2                     96           Placed  550000       False          False
# ...

# %%
# Student Dataset: Dummies for Department
import pandas as pd
df = pd.read_csv("Student_Dataset_Exp15.csv")

dept_dummies = pd.get_dummies(df['Department'], drop_first=True)

df = pd.concat([df, dept_dummies], axis=1)

df
# Out:
#    Roll_No  Gender  Department  CGPA  Number_of_Backlogs  \
# 0      101  Female    Computer   8.2                   0
# 1      102    Male          IT   7.5                   1
# 2      103  Female        ENTC   9.1                   0
# 3      104    Male  Mechanical   6.8                   2
# 4      105  Female    Computer   8.7                   0
# 5      106    Male       Civil   7.2                   3
# 6      107  Female          IT   8.9                   0
# 7      108    Male    Computer   6.5                   1
# 8      109  Female        ENTC   7.8                   0
# 9      110    Male  Mechanical   7.0                   2
#
#    Attendance_Percentage Placement_Status  Salary  Computer   ENTC     IT  \
# 0                     92           Placed  450000      True  False  False
# 1                     85       Not Placed       0     False  False   True
# 2                     96           Placed  550000     False   True  False
# ...
