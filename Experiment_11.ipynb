# %%
# Experiment No. 11 - Create Dataset and Load Dataset
# Name: Rachit Jajoo
# PRN: 25070123088
# Batch: ENTC - B1

# %%
# Code 1: Dataset creation
import pandas as pd
data = {
    "Roll Number": [101,102,103,104,105],
    "Gender": ["Male","Female","Female","Male","Male"],
    "Department": ["Computer Science", "IT", "ENTC", "Mechanical", "Computer Science"],
    "CGPA": [8.2,7.5,9.1,6.8,8.7]
}

df = pd.DataFrame(data)
df.to_csv("student_data.csv", index=False)
print(df)
df
# Out:
#    Roll Number  Gender        Department  CGPA
# 0          101    Male  Computer Science   8.2
# 1          102  Female                IT   7.5
# 2          103  Female              ENTC   9.1
# 3          104    Male        Mechanical   6.8
# 4          105    Male  Computer Science   8.7
#    Roll Number  Gender        Department  CGPA
# 0          101    Male  Computer Science   8.2
# 1          102  Female                IT   7.5
# 2          103  Female              ENTC   9.1
# 3          104    Male        Mechanical   6.8
# 4          105    Male  Computer Science   8.7

# %%
# Code 2: To perform operations in Panda library
# Just learning some new commands in dataframe
df.shape
df.size
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Roll Number  5 non-null      int64
#  1   Gender       5 non-null      object
#  2   Department   5 non-null      object
#  3   CGPA         5 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 292.0+ bytes

# %%
# Code 3: To describe the dataset
df.describe()
# Out:
#        Roll Number     CGPA
# count     5.000000  5.00000
# mean    103.000000  8.06000
# std       1.581139  0.92358
# min     101.000000  6.80000
# 25%     102.000000  7.50000
# 50%     103.000000  8.20000
# 75%     104.000000  8.70000
# max     105.000000  9.10000

# %%
# Code 4: To upload a dataset
import pandas as pd
import numpy as np
df = pd.read_csv("Cars93.csv")
df
# Out:
#      Manufacturer           Model     Type  Price  MPG.city  \
# 0           Acura         Integra    Small   15.9        25
# 1           Acura          Legend  Midsize   33.9        18
# 2            Audi              90  Compact   29.1        20
# 3            Audi             100  Midsize   37.7        19
# 4             BMW            535i  Midsize   30.0        22
# 5           Buick         Century  Midsize   15.7        22
# 6           Buick         LeSabre    Large   20.8        19
# 7           Buick      Roadmaster    Large   23.7        16
# 8           Buick         Riviera  Midsize   26.3        19
# 9        Cadillac         DeVille    Large   34.7        16
# 10       Cadillac         Seville  Midsize   40.1        16
# 11      Chevrolet        Cavalier  Compact   13.4        25
# 12      Chevrolet         Corsica  Compact   11.4        25
# 13      Chevrolet          Camaro   Sporty   15.1        19
# 14      Chevrolet          Lumina  Midsize   15.9        21
# ...

# %%
# Code 4.1 - Operations on uploaded dataset
print(df.size)
# Out:
# 930

# %%
# Code 4.2 - Operations on uploaded dataset
print(df.shape)
# Out:
# (93, 10)

# %%
# Code 4.3 - Operations on uploaded dataset
print(df.describe())
# Out:
#            Price   MPG.city  Horsepower  Passengers  Rear.seat.room  \
# count  93.000000  93.000000   93.000000   93.000000       91.000000
# mean   19.509677  22.365591  143.827957    5.086022       27.829670
# std     9.659430   5.619812   52.374410    1.038979        2.989072
# min     7.400000  15.000000   55.000000    2.000000       19.000000
# 25%    12.200000  18.000000  103.000000    4.000000       26.000000
# 50%    17.700000  21.000000  140.000000    5.000000       27.500000
# 75%    23.300000  25.000000  170.000000    6.000000       30.000000
# max    61.900000  46.000000  300.000000    8.000000       36.000000
#
#        Luggage.room
# count     82.000000
# mean      13.890244
# std        2.997967
# min        6.000000
# 25%       12.000000
# 50%       14.000000
# 75%       15.000000
# max       22.000000

# %%
# Code 4.4 - Operations on uploaded dataset
print(df.head())
# Out:
#   Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 0        Acura  Integra    Small   15.9        25                 NaN
# 1        Acura   Legend  Midsize   33.9        18  Driver & Passenger
# 2         Audi       90  Compact   29.1        20         Driver only
# 3         Audi      100  Midsize   37.7        19  Driver & Passenger
# 4          BMW     535i  Midsize   30.0        22         Driver only
#
#    Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0         140           5            26.5          11.0
# 1         200           5            30.0          15.0
# 2         172           5            28.0          14.0
# 3         172           6            31.0          17.0
# 4         208           4            27.0          13.0

# %%
# Code 4.5 - Operations on uploaded dataset
print(df.tail())
# Out:
#    Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 88   Volkswagen  Eurovan      Van   19.7        17                 NaN
# 89   Volkswagen   Passat  Compact   20.0        21                 NaN
# 90   Volkswagen  Corrado   Sporty   23.3        18                 NaN
# 91        Volvo      240  Compact   22.7        21         Driver only
# 92        Volvo      850  Midsize   26.7        20  Driver & Passenger
#
#     Horsepower  Passengers  Rear.seat.room  Luggage.room
# 88         109           7            34.0           NaN
# 89         134           5            31.5          14.0
# 90         178           4            26.0          15.0
# 91         114           5            29.5          14.0
# 92         168           5            30.0          15.0

# %%
# Code 4.6 - Operations on uploaded dataset
print(df.columns)
# Out:
# Index(['Manufacturer', 'Model', 'Type', 'Price', 'MPG.city', 'AirBags',
#        'Horsepower', 'Passengers', 'Rear.seat.room', 'Luggage.room'],
#       dtype='object')

# %%
# Code 4.7 - Operations on uploaded dataset
print(df.sample(5))
# Out:
#    Manufacturer   Model     Type  Price  MPG.city      AirBags  Horsepower  \
# 66       Nissan  Maxima  Midsize   21.5        21  Driver only         160
# 71     Plymouth   Laser   Sporty   14.4        23          NaN          92
# 47     Infiniti     Q45  Midsize   47.9        17  Driver only         278
# 41        Honda   Civic    Small   12.1        42  Driver only         102
# 87   Volkswagen     Fox    Small    9.1        25          NaN          81
#
#     Passengers  Rear.seat.room  Luggage.room
# 66           5            28.5          14.0
# 71           4            24.5           8.0
# 47           5            29.0          15.0
# 41           4            28.0          12.0
# 87           4            26.0          10.0

# %%
# Code 4.8 - Operations on uploaded dataset
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Manufacturer    93 non-null     object
#  1   Model           93 non-null     object
#  2   Type            93 non-null     object
#  3   Price           93 non-null     float64
#  4   MPG.city        93 non-null     int64
#  5   AirBags         59 non-null     object
#  6   Horsepower      93 non-null     int64
#  7   Passengers      93 non-null     int64
#  8   Rear.seat.room  91 non-null     float64
#  9   Luggage.room    82 non-null     float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 7.4+ KB
# None

# %%
# Code 4.9 - Operations on uploaded dataset
print(df.dtypes)
# Out:
# Manufacturer       object
# Model              object
# Type               object
# Price             float64
# MPG.city            int64
# AirBags            object
# Horsepower          int64
# Passengers          int64
# Rear.seat.room    float64
# Luggage.room      float64
# dtype: object

# %%
# Code 4.10 - Operations on uploaded dataset
df.isnull().sum()
# Out:
# Manufacturer       0
# Model              0
# Type               0
# Price              0
# MPG.city           0
# AirBags           34
# Horsepower         0
# Passengers         0
# Rear.seat.room     2
# Luggage.room      11
# dtype: int64

# %%
# Code 4.11 - Operations on uploaded dataset
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Code 4.12 - Operations on uploaded dataset
df.nunique()
# Out:
# Manufacturer      32
# Model             93
# Type               6
# Price             81
# MPG.city          21
# AirBags            2
# Horsepower        57
# Passengers         6
# Rear.seat.room    24
# Luggage.room      16
# dtype: int64
